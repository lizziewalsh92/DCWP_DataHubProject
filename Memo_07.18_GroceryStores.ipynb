# %%
import pandas as pd

# %%
dfGC = pd.read_csv("Charges_Grocery_Supermarket.csv")

# %%
dfGC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1516 entries, 0 to 1515
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Record ID                  1482 non-null   object
#  1   Related Record Type        1482 non-null   object
#  2   Business Unique ID         1482 non-null   object
#  3   Business Name              1482 non-null   object
#  4   DBA/Trade Name             304 non-null    object
#  5   Business Category          1482 non-null   object
#  6   Certificate of Inspection  1481 non-null   object
#  7   Inspection Number          1481 non-null   object
#  8   NOH Number                 1482 non-null   object
#  9   Violation Date             1482 non-null   object
#  10  Charge                     1482 non-null   object
#  11  Charge Count               1482 non-null   float64
#  12  Cure Eligible              617 non-null    object
# ...

# %%
dfALL = pd.read_csv("Charges_2.csv")

# %%
dfALL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80712 entries, 0 to 80711
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Record ID                  80712 non-null  object
#  1   Related Record Type        80712 non-null  object
#  2   Business Unique ID         80712 non-null  object
#  3   Business Name              80712 non-null  object
#  4   DBA/Trade Name             7057 non-null   object
#  5   Business Category          80708 non-null  object
#  6   Certificate of Inspection  79688 non-null  object
#  7   Inspection Number          79700 non-null  object
#  8   NOH Number                 80712 non-null  object
#  9   Violation Date             80712 non-null  object
#  10  Charge                     80712 non-null  object
#  11  Charge Count               80708 non-null  float64
#  12  Cure Eligible              71630 non-null  object
# ...

# %%
dfGC["Business Category"].value_counts()
# Out:
# Business Category
# Grocery-Retail    1030
# Supermarket        452
# Name: count, dtype: int64

# %%
1030/1482
# Out:
# 0.6950067476383266

# %%
unique_cats_violations = dfALL[["Business Category"]].value_counts()

# %%
unique_categories = dfALL["Business Category"].value_counts().index.tolist()

# %%
print(unique_categories)
# Out:
# ['Tobacco Retail Dealer', 'Electronic Cigarette Dealer', 'Grocery-Retail', 'Supermarket', 'Misc Non-Food Retail', 'Garage & Parking Lot', 'Salons And Barbershop', 'Retail Laundry', 'Micromobility Device Store', 'Stoop Line Stand', 'Tax Preparers', 'Drug Store Retail', 'Car Wash', 'Home Improvement Contractor', 'Restaurant', 'Garage', 'Gas Station-Retail', 'Secondhand Dealer - General', 'Electronics Store', 'Secondhand Dealer - Auto', 'Wearing Apparel', 'Process Server Individual', 'Immigration Service Provider', 'Newsstand', 'Tow Truck Company', 'Electronic & Home Appliance Service Dealer', 'Parking Lot', 'Specialized Vending License - MFV', 'Hardware-Retail', 'Fuel Oil Dealer', 'Furniture Sales', 'Dry Cleaners', 'Pawnbroker', 'Employment Agency', 'Jewelry Store-Retail', 'Auto Rental', 'Dealer In Products For The Disabled', 'Debt Collection Agency', 'Sightseeing Bus', 'Megastore', 'Industrial Laundry', 'Retail Store', 'Movie Theater/Entertainment Venue', 'Funeral Homes', 'Booting Com
# ...

# %%
## how many business categories?
dfALL["Business Category"].nunique()
# Out:
# 61

# %%
dfGC[["Business Category"]].value_counts()
# Out:
# Business Category
# Grocery-Retail       1030
# Supermarket           452
# Name: count, dtype: int64

# %%
dfSupermarket = dfGC.query("`Business Category`=='Supermarket'")

# %%
dfGROCVios = dfGC.query("`Business Category`=='Grocery-Retail'")

# %%
dfWHOLEVios = dfGC.query("`Business Category`=='Grocery-Retail'")

# %%
dfGROCVios = dfGROCVios.drop_duplicates(subset='Business Unique ID', keep='last')

# %%
dfGROCVios.sort_values('Charge Count', ascending = False)
# Out:
#            Record ID     Related Record Type Business Unique ID  \
# 0    39669-2025-ADJC  dcwp_InspectionRequest    BA-1725618-2025
# 813  22593-2024-ADJC  dcwp_InspectionRequest    BA-1693901-2024
# 865  28655-2024-ADJC  dcwp_InspectionRequest    BA-1310737-2022
# 861  21773-2024-ADJC  dcwp_InspectionRequest    BA-1419598-2022
# 859  21669-2024-ADJC  dcwp_InspectionRequest    BA-1691165-2024
# ..               ...                     ...                ...
# 279  15530-2023-ADJC  dcwp_InspectionRequest    BA-1655414-2023
# 913  29901-2024-ADJC  dcwp_InspectionRequest    BA-1230140-2022
# 912  19718-2024-ADJC  dcwp_InspectionRequest    BA-1200214-2022
# 911  20180-2024-ADJC  dcwp_InspectionRequest    BA-1681689-2023
# 995  17990-2024-ADJC  dcwp_InspectionRequest    BA-1520427-2022
#
#                        Business Name   DBA/Trade Name Business Category  \
# 0             BARUIR COFFEE SHOP LLC              NaN    Grocery-Retail
# ...

# %%
##top grocery store violators by charge count
dfGROCVios.head(5)
# Out:
#          Record ID     Related Record Type Business Unique ID  \
# 0  39669-2025-ADJC  dcwp_InspectionRequest    BA-1725618-2025
# 1  10016-2023-ADJC  dcwp_InspectionRequest    BA-1584016-2023
# 2  39568-2025-ADJC  dcwp_InspectionRequest    BA-1239469-2022
# 3  10024-2023-ADJC  dcwp_InspectionRequest    BA-1516146-2022
# 4  10030-2023-ADJC  dcwp_InspectionRequest    BA-1175745-2022
#
#                    Business Name DBA/Trade Name Business Category  \
# 0         BARUIR COFFEE SHOP LLC            NaN    Grocery-Retail
# 1          SUNSET PARK DELI CORP            NaN    Grocery-Retail
# 2       DAVIEL DELI GROCERY CORP            NaN    Grocery-Retail
# 3       STANLEY MINI MARKET CORP            NaN    Grocery-Retail
# 4  FARM IN THE MYRTLE DELI, INC.            NaN    Grocery-Retail
#
#   Certificate of Inspection Inspection Number NOH Number Violation Date  \
# 0                  A0218732     INS-000842402   25Q00843     03/28/2025
# ...

# %%
## find number of violations for supermarkets-- 359
dfSupermarketVios = dfSupermarket.drop_duplicates(subset='Business Unique ID', keep='last')

# %%
dfSupermarketVios.to_csv("SupermarketCharges.csv")

# %% [markdown]
# INSPECTIONS AND CONFISCATIONS

# %%
FoodInspections = pd.read_csv("FoodRetailerConf_ALL.csv")

# %%
FoodInspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8826 entries, 0 to 8825
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Certificate of Inspection      8826 non-null   object
#  1   Inspection Number              8826 non-null   object
#  2   Date of Occurance              8826 non-null   object
#  3   Year (added)                   8826 non-null   object
#  4   Business Unique ID             8820 non-null   object
#  5   UniqueBusinessID_NoYear        8820 non-null   object
#  6   Business Name                  8826 non-null   object
#  7   DBA Trade Name                 2419 non-null   object
#  8   Business Category              8826 non-null   object
#  9   Inspection type                8826 non-null   object
#  10  Device Category                8826 non-null   object
#  11  Device Class                   8791 non-null   object
# ...

# %%
FoodInspections[["Business Category"]].value_counts()
# Out:
# Business Category
# Grocery-Retail - 808           4792
# Supermarket - 819              3985
# Wholesale Food Market - 718      49
# Name: count, dtype: int64

# %%
FoodInspections.sort_values(by='Date of Occurance', ascending=False)
# Out:
#      Certificate of Inspection Inspection Number Date of Occurance  \
# 2686                  A0205653     INS-000816733        12/31/2024
# 6481                  A0205689     INS-000816790        12/31/2024
# 4999                  A0205679     INS-000816770        12/31/2024
# 357                   A0205670     INS-000816759        12/31/2024
# 3332                  A0205670     INS-000816759        12/31/2024
# ...                        ...               ...               ...
# 2592                  A0148788     INS-000699873        01/02/2024
# 3744                  A0148800     INS-000699896        01/02/2024
# 7544                  A0148734     INS-000699795        01/02/2024
# 5724                  A0148802     INS-000699901        01/02/2024
# 3743                  A0148800     INS-000699896        01/02/2024
#
#      Year (added) Business Unique ID UniqueBusinessID_NoYear  \
# 2686         2024    BA-1442880-2022              BA-1442880
# ...

# %%
FoodInspections.drop_duplicates(subset='UniqueBusinessID_NoYear', keep='last')
# Out:
#      Certificate of Inspection Inspection Number Date of Occurance  \
# 14                    A0200942     INS-000804414        11/26/2024
# 77                    A0191624     INS-000789240        10/02/2024
# 91                    A0185672     INS-000778385        08/29/2024
# 116                   A0196906     INS-000793824        10/31/2024
# 118                   A0149537     INS-000699233        01/09/2024
# ...                        ...               ...               ...
# 8818                  A0211380     INS-000828831        02/11/2025
# 8821                  A0153288     INS-000712001        02/05/2024
# 8823                  A0211276     INS-000828679        02/11/2025
# 8824                  A0181228     INS-000769245        08/02/2024
# 8825                  A0179388     INS-000764707        07/23/2024
#
#      Year (added) Business Unique ID UniqueBusinessID_NoYear  \
# 14           2024    BA-1714440-2024              BA-1714440
# ...

# %%
FoodInspections.drop_duplicates(subset='Business Unique ID', keep='last')
# Out:
#      Certificate of Inspection Inspection Number Date of Occurance  \
# 14                    A0200942     INS-000804414        11/26/2024
# 77                    A0191624     INS-000789240        10/02/2024
# 91                    A0185672     INS-000778385        08/29/2024
# 116                   A0196906     INS-000793824        10/31/2024
# 118                   A0149537     INS-000699233        01/09/2024
# ...                        ...               ...               ...
# 8818                  A0211380     INS-000828831        02/11/2025
# 8821                  A0153288     INS-000712001        02/05/2024
# 8823                  A0211276     INS-000828679        02/11/2025
# 8824                  A0181228     INS-000769245        08/02/2024
# 8825                  A0179388     INS-000764707        07/23/2024
#
#      Year (added) Business Unique ID UniqueBusinessID_NoYear  \
# 14           2024    BA-1714440-2024              BA-1714440
# ...

# %%
SUPEInspections = FoodInspections.query("`Business Category`=='Supermarket - 819'")

# %%
GROCInspections = FoodInspections.query("`Business Category`=='Grocery-Retail - 808'")

# %%
WHOLEInspections = FoodInspections.query("`Business Category`=='Wholesale Food Market - 718'")

# %%
SUPEInspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3985 entries, 0 to 4033
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Certificate of Inspection      3985 non-null   object
#  1   Inspection Number              3985 non-null   object
#  2   Date of Occurance              3985 non-null   object
#  3   Year (added)                   3985 non-null   object
#  4   Business Unique ID             3983 non-null   object
#  5   UniqueBusinessID_NoYear        3983 non-null   object
#  6   Business Name                  3985 non-null   object
#  7   DBA Trade Name                 1653 non-null   object
#  8   Business Category              3985 non-null   object
#  9   Inspection type                3985 non-null   object
#  10  Device Category                3985 non-null   object
#  11  Device Class                   3973 non-null   object
# ...

# %%
SUPEConfInspections = SUPEInspections.query("`Devices Condemned/Confiscated` > 0")

# %%
GROCConfInspections = GROCInspections.query("`Devices Condemned/Confiscated` > 0")

# %%
GROCConfInspections.sort_values('Devices Condemned/Confiscated', ascending = False)
# Out:
#      Certificate of Inspection Inspection Number Date of Occurance  \
# 6305                  A0190399     INS-000787054        09/26/2024
# 7300                  A0162386     INS-000731913        04/05/2024
# 6503                  A0188361     INS-000785368        09/17/2024
# 8199                  A0187256     INS-000781391        09/10/2024
# 4100                  A0202625     INS-000810921        12/06/2024
# 4753                  A0177190     INS-000760345        07/09/2024
# 6304                  A0166954     INS-000739789        05/02/2024
# 5662                  A0171842     INS-000749613        05/31/2024
# 6218                  A0154772     INS-000717591        02/16/2024
# 7400                  A0178415     INS-000762832        07/17/2024
# 5826                  A0190608     INS-000778173        09/26/2024
# 6126                  A0180040     INS-000766726        07/26/2024
# 7561                  A0197617     INS-000801526        11/06/2024
# ...

# %%
SUPEConfInspections["Business Unique ID"].value_counts()
# Out:
# Business Unique ID
# BA-1641965-2023    3
# BA-1402553-2022    3
# BA-1460189-2022    2
# BA-1200637-2022    2
# BA-1547869-2022    2
# BA-1119903-2022    2
# BA-1504165-2022    2
# BA-1722159-2025    2
# BA-1102781-2022    1
# BA-1682507-2024    1
# BA-1105393-2022    1
# BA-966535-2022     1
# BA-1559348-2022    1
# BA-1125576-2022    1
# BA-1084519-2022    1
# BA-1682124-2024    1
# BA-991760-2022     1
# BA-1709418-2024    1
# BA-1635802-2023    1
# BA-1106514-2022    1
# BA-1200670-2022    1
# BA-1122304-2022    1
# BA-1722356-2025    1
# BA-1126212-2022    1
# BA-1108214-2022    1
# BA-1102863-2022    1
# BA-1095829-2022    1
# BA-1600499-2023    1
# BA-1664090-2023    1
# BA-1126555-2022    1
# BA-1248176-2022    1
# BA-1184052-2022    1
# BA-1204280-2022    1
# BA-1468736-2022    1
# BA-1515506-2022    1
# BA-1681549-2023    1
# BA-1617911-2023    1
# BA-1265605-2022    1
# BA-1692104-2024    1
# BA-1451784-2022    1
# BA-1427902-2022    1
# BA-1445937-2022    1
# ...

# %%
SUPEConfInspections.value_counts('Devices Condemned/Confiscated')
# Out:
# Devices Condemned/Confiscated
# 1    22
# 3    17
# 4    13
# 2    12
# 6     3
# Name: count, dtype: int64

# %%
SUPEConfInspections.sort_values('Devices Condemned/Confiscated', ascending = False)
# Out:
#      Certificate of Inspection Inspection Number Date of Occurance  \
# 2616                  A0157584     INS-000710522        03/08/2024
# 3775                  A0159416     INS-000726616        03/20/2024
# 3892                  A0162293     INS-000731768        04/05/2024
# 2509                  A0177017     INS-000759988        07/09/2024
# 3114                  A0155485     INS-000731779        02/23/2024
# ...                        ...               ...               ...
# 2598                  A0203747     INS-000812984        12/13/2024
# 2497                  A0217374     INS-000839092        03/20/2025
# 2346                  A0208801     INS-000822706        01/24/2025
# 2321                  A0146939     INS-000738275        12/14/2023
# 4016                  A0212301     INS-000830463        02/18/2025
#
#      Year (added) Business Unique ID UniqueBusinessID_NoYear  \
# 2616         2024    BA-1453747-2022              BA-1453747
# ...

# %%
SUPEConfInspections.to_csv("Supermarkets With Confiscations.csv")

# %%
GROCInspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4792 entries, 4034 to 8825
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Certificate of Inspection      4792 non-null   object
#  1   Inspection Number              4792 non-null   object
#  2   Date of Occurance              4792 non-null   object
#  3   Year (added)                   4792 non-null   object
#  4   Business Unique ID             4788 non-null   object
#  5   UniqueBusinessID_NoYear        4788 non-null   object
#  6   Business Name                  4792 non-null   object
#  7   DBA Trade Name                 759 non-null    object
#  8   Business Category              4792 non-null   object
#  9   Inspection type                4792 non-null   object
#  10  Device Category                4792 non-null   object
#  11  Device Class                   4770 non-null   object
# ...

# %%
GROCConfInspections.value_counts('Business Unique ID', ascending = False)
# Out:
# Business Unique ID
# BA-1690979-2024    2
# BA-1001621-2022    1
# BA-1666365-2023    1
# BA-1596353-2023    1
# BA-1596402-2023    1
# BA-1597771-2023    1
# BA-1616765-2023    1
# BA-1628903-2023    1
# BA-1631875-2023    1
# BA-1642873-2023    1
# BA-1677877-2023    1
# BA-1002976-2022    1
# BA-1679440-2023    1
# BA-1690494-2024    1
# BA-1707531-2024    1
# BA-1708856-2024    1
# BA-1716203-2024    1
# BA-1720823-2025    1
# BA-1721260-2025    1
# BA-1582436-2023    1
# BA-1572278-2023    1
# BA-1534786-2022    1
# BA-1227987-2022    1
# BA-1107968-2022    1
# BA-1121078-2022    1
# BA-1168744-2022    1
# BA-1202042-2022    1
# BA-1208677-2022    1
# BA-1209860-2022    1
# BA-1219880-2022    1
# BA-1282904-2022    1
# BA-1520854-2022    1
# BA-1321896-2022    1
# BA-1329374-2022    1
# BA-1335574-2022    1
# BA-1412248-2022    1
# BA-1429125-2022    1
# BA-1451804-2022    1
# BA-1484729-2022    1
# BA-1722946-2025    1
# Name: count, dtype: int64

# %%
GROCConfInspections.sort_values('', ascending = False)

# %%
GROCConfInspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41 entries, 4079 to 8727
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Certificate of Inspection      41 non-null     object
#  1   Inspection Number              41 non-null     object
#  2   Date of Occurance              41 non-null     object
#  3   Year (added)                   41 non-null     object
#  4   Business Unique ID             41 non-null     object
#  5   UniqueBusinessID_NoYear        41 non-null     object
#  6   Business Name                  41 non-null     object
#  7   DBA Trade Name                 9 non-null      object
#  8   Business Category              41 non-null     object
#  9   Inspection type                41 non-null     object
#  10  Device Category                41 non-null     object
#  11  Device Class                   37 non-null     object
# ...

# %%
GROCConfInspections.to_csv("GroceryStoreConfiscations.csv")

# %%
WHOLEInspections.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, 7 to 1663
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Certificate of Inspection      49 non-null     object
#  1   Inspection Number              49 non-null     object
#  2   Date of Occurance              49 non-null     object
#  3   Year (added)                   49 non-null     object
#  4   Business Unique ID             49 non-null     object
#  5   UniqueBusinessID_NoYear        49 non-null     object
#  6   Business Name                  49 non-null     object
#  7   DBA Trade Name                 7 non-null      object
#  8   Business Category              49 non-null     object
#  9   Inspection type                49 non-null     object
#  10  Device Category                49 non-null     object
#  11  Device Class                   48 non-null     object
# ...

# %%
WHOLEInspections.to_csv("Wholesale Food Confiscations.csv")

# %%
WHOLEInspections.sort_values('Devices Condemned/Confiscated', ascending = False)
# Out:
#      Certificate of Inspection Inspection Number Date of Occurance  \
# 829                   A0192175     INS-000790344        10/04/2024
# 629                   A0192275     INS-000815755        10/04/2024
# 7                     A0200942     INS-000804414        11/26/2024
# 1373                  A0192254     INS-000790502        10/04/2024
# 1191                  A0192295     INS-000790579        10/04/2024
# 1192                  A0162243     INS-000725642        04/05/2024
# 1200                  A0191760     INS-000789494        10/02/2024
# 1251                  A0217161     INS-000832082        03/20/2025
# 1265                  A0217161     INS-000832082        03/20/2025
# 1312                  A0165233     INS-000734701        04/24/2024
# 1323                  A0186269     INS-000777390        09/04/2024
# 1369                  A0191528     INS-000788762        10/02/2024
# 1397                  A0216338     INS-000837260        03/14/2025
# ...

# %%
WHOLEConfInspections = WHOLEInspections.query("`Devices Condemned/Confiscated` > 0")

# %%
WHOLEConfInspections.sort_values('Devices Condemned/Confiscated', ascending = False)
# Out:
#     Certificate of Inspection Inspection Number Date of Occurance  \
# 829                  A0192175     INS-000790344        10/04/2024
# 629                  A0192275     INS-000815755        10/04/2024
#
#     Year (added) Business Unique ID UniqueBusinessID_NoYear  \
# 829         2024    BA-1710814-2024              BA-1710814
# 629         2024    BA-1710841-2024              BA-1710841
#
#                Business Name DBA Trade Name            Business Category  \
# 829     MADURA, JOHN D FARMS            NaN  Wholesale Food Market - 718
# 629  SAMASCOTT ORCHARDS, LLC            NaN  Wholesale Food Market - 718
#
#     Inspection type  ... State Postcode    Borough  Community Board  \
# 829           Scale  ...    NY    10003  Manhattan            105.0
# 629           Scale  ...    NY    10003  Manhattan            105.0
#
#      Council District  BIN BBL  NTA   Latitude  Longitude
# 829               2.0  NaN NaN  NaN  40.736531 -73.990752
# ...
